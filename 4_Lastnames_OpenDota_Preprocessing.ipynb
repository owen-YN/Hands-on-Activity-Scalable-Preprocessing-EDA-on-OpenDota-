# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("OpenDota_Preprocessing") \
    .getOrCreate()

print("Spark version:", spark.version)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("OpenDota_Preprocessing") \
# ----> 5     .getOrCreate()
#       7 print("Spark version:", spark.version)
#
# File d:\project_BIGD\.venv\Lib\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File d:\project_BIGD\.venv\Lib\site-packages\pyspark\sql\session.py:636, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
# ...
